# %%
import pandas as pd
import os

# %% [markdown]
# ### data preview

# %%
data_path = '/Users/ryan/Documents/GitHub/MGT4187-Project/data'

# %%
os.chdir(data_path)
profit = pd.read_csv('movie_profit.csv', index_col=0)

print(profit.columns)

# check the nan value in production budget col
print('nan value in production budget: ', profit['production_budget'].isna().sum())
profit.sample(10)
# Out:
# Index(['release_date', 'movie', 'production_budget', 'domestic_gross',
#        'worldwide_gross', 'distributor', 'mpaa_rating', 'genre'],
#       dtype='object')
# nan value in production budget:  0
#      release_date                       movie  production_budget  \
# 1155    2/25/2005                      Cursed         35000000.0
# 1885    6/24/1970                    Catch-22         18000000.0
# 2841    3/23/2018     Paul, Apostle of Christ          5000000.0
# 200     10/5/2018                       Venom        100000000.0
# 1758     4/8/2005              Kung Fu Hustle         20000000.0
# 2144    2/24/2012    Tyler Perry's Good Deeds         14000000.0
# 312     6/30/1995                 Judge Dredd         85000000.0
# 2202     3/1/2013                 21 and Over         13000000.0
# 2135   12/20/1989  Born on the Fourth of July         14000000.0
# 1626   11/11/2005                    Derailed         22000000.0
#
#       domestic_gross  worldwide_gross             distributor mpaa_rating  \
# 1155      19294901.0       25114901.0       Miramax/Dimension       PG-13
# 1885      24911670.0       24911670.0      Paramount Pictures         NaN
# 2841      17547999.0       23389835.0           Sony Pictures       PG-13
# 200      171125095.0      461825095.0           Sony Pictures       PG-13
# 1758      17104669.0      102034104.0  Sony Pictures Classics           R
# 2144      35025791.0       35579177.0               Lionsgate       PG-13
# 312       34687912.0      113487912.0             Walt Disney           R
# 2202      25682380.0       42195766.0              Relativity           R
# 2135      70001698.0       70001698.0               Universal           R
# 1626      36020063.0       57520063.0           Weinstein Co.           R
#
#        genre
# 1155  Horror
# 1885  Comedy
# 2841   Drama
# 200   Action
# 1758  Action
# 2144   Drama
# 312   Action
# 2202  Comedy
# 2135   Drama
# 1626  Action

# %%
disney_plus = pd.read_csv('disney_plus_shows.csv')

print(disney_plus.columns)
disney_plus.sample(5)
# Out:
# Index(['imdb_id', 'title', 'plot', 'type', 'rated', 'year', 'released_at',
#        'added_at', 'runtime', 'genre', 'director', 'writer', 'actors',
#        'language', 'country', 'awards', 'metascore', 'imdb_rating',
#        'imdb_votes'],
#       dtype='object')
#         imdb_id                       title  \
# 160   tt1376699                 Den Brother
# 91    tt0109369                Camp Nowhere
# 221  tt12100080        Diving with Dolphins
# 474   tt0103584  X-Men: The Animated Series
# 19    tt0043274         Alice in Wonderland
#
#                                                   plot    type      rated  \
# 160  A high school hockey player forced to lead his...   movie  Not Rated
# 91   A group of junior high kids don't want to go t...   movie         PG
# 221  A documentary showing the making of "Dolphin R...   movie        NaN
# 474  A team of mutant superheroes fight for justice...  series      TV-Y7
# 19   Alice stumbles into the world of Wonderland. W...   movie          G
#
#           year  released_at           added_at runtime  \
# 160       2010  13 Aug 2010  November 12, 2019  89 min
# 91        1994  26 Aug 1994  November 12, 2019  96 min
# 221       2020  03 Apr 2020      April 3, 2020  79 min
# 474  1992–1997  31 Oct 1992  November 12, 2019  23 min
# 19        1951  14 Sep 1951  November 12, 2019  75 min
#
#                                               genre  \
# 160                          Family, Romance, Sport
# 91                        Adventure, Comedy, Family
# 221                                     Documentary
# 474     Animation, Action, Family, Sci-Fi, Thriller
# 19   Animation, Adventure, Family, Fantasy, Musical
#
#                                             director  \
# 160                                   Mark L. Taylor
# 91                                   Jonathan Prince
# 221                                    Keith Scholey
# 474                                              NaN
# 19   Clyde Geronimi, Wilfred Jackson, Hamilton Luske
#
#                                                 writer  \
# 160   James Krieg (teleplay), Michael Horowitz (story)
# 91                         Andrew Kurtzman, Eliot Wald
# 221                                                NaN
# 474  Mark Edward Edens, Sidney Iwanter, Eric Lewald...
# 19   Lewis Carroll (adaptation), Winston Hibler (st...
#
#                                                 actors language      country  \
# 160  Hutch Dano, Genevieve Hannelius, Vicki Lewis, ...  English          USA
# 91   John Putch, Peter Scolari, Romy Windsor, Jonat...  English          USA
# 221                  Celine Cousteau, Daniel Rasmussen  English          USA
# 474  Cathal J. Dodd, George Buza, Norm Spencer, Ced...  English  USA, Canada
# 19   Kathryn Beaumont, Ed Wynn, Richard Haydn, Ster...  English          USA
#
#                                            awards  metascore  imdb_rating  \
# 160                                           NaN        NaN          5.4
# 91                                            NaN        NaN          6.1
# 221                                           NaN        NaN          7.4
# 474                                           NaN        NaN          8.4
# 19   Nominated for 1 Oscar. Another 1 nomination.       68.0          7.4
#
#     imdb_votes
# 160      1,666
# 91       8,448
# 221         18
# 474     36,206
# 19     123,377

# %% [markdown]
# ### match with profit dataset

# %%
profit.rename(columns={'movie': 'title'}, inplace=True)

disney_plus = pd.merge(disney_plus, profit[['title', 'production_budget', 'domestic_gross', 'worldwide_gross', 'distributor', 'mpaa_rating']], on='title', how='left')

# check the matched pairs
disney_plus['matched_profit_indicator'] = disney_plus['production_budget'].notnull().astype(int)
print(f'the original length: {disney_plus.__len__()}; the matched pairs: {disney_plus.matched_profit_indicator.sum()}')
# Out:
# the original length: 992; the matched pairs: 123

# %%
disney_plus.sample(5)
# Out:
#        imdb_id                         title  \
# 391  tt0110157                     Iron Will
# 184  tt3008594            Minnie's Bow-Toons
# 149  tt0377770                       Destino
# 658  tt3748528  Rogue One: A Star Wars Story
# 845  tt0246834                  The Other Me
#
#                                                   plot    type  rated  \
# 391  A brave young man is thrust into adulthood as ...   movie     PG
# 184  Minnie and daisy open a bow shop in which they...  series    NaN
# 149  To a song of love lost and rediscovered, a wom...   movie     PG
# 658  The daughter of an Imperial scientist joins th...   movie  PG-13
# 845  Will Browning accidentally creates a clone of ...   movie   TV-G
#
#           year  released_at           added_at  runtime  \
# 391       1994  14 Jan 1994  November 12, 2019  108 min
# 184  2011–2016  14 Nov 2011  November 12, 2019      NaN
# 149       2003  05 Aug 2003   January 10, 2020    7 min
# 658       2016  16 Dec 2016  November 12, 2019  133 min
# 845       2000  08 Sep 2000  November 12, 2019   90 min
#
#                          genre  ...  \
# 391          Adventure, Family  ...
# 184                  Animation  ...
# 149           Animation, Short  ...
# 658  Action, Adventure, Sci-Fi  ...
# 845     Comedy, Family, Sci-Fi  ...
#
#                                                 awards metascore imdb_rating  \
# 391                                                NaN      56.0         6.6
# 184                              1 win & 1 nomination.       NaN         6.5
# 149  Nominated for 1 Oscar. Another 6 wins & 1 nomi...       NaN         7.9
# 658  Nominated for 2 Oscars. Another 24 wins & 80 n...      65.0         7.8
# 845                             2 wins & 1 nomination.       NaN         6.1
#
#     imdb_votes production_budget domestic_gross  worldwide_gross  distributor  \
# 391      7,095               NaN            NaN              NaN          NaN
# 184         35               NaN            NaN              NaN          NaN
# 149      3,695               NaN            NaN              NaN          NaN
# 658    526,836               NaN            NaN              NaN          NaN
# 845      1,741               NaN            NaN              NaN          NaN
#
#     mpaa_rating  matched_profit_indicator
# 391         NaN                         0
# 184         NaN                         0
# 149         NaN                         0
# 658         NaN                         0
# 845         NaN                         0
#
# [5 rows x 25 columns]

# %% [markdown]
# ### match within the review data

# %%
review_path = '/Users/ryan/Documents/GitHub/MGT4187-Project/data/review_data'
os.chdir(review_path)

audience = pd.read_csv('audience_reviews.csv')
print(audience.columns)
print(f'total length of audience review data: {audience.__len__()}; unique show: {audience.Show.unique().__len__()}')
audience.sample(5)
# Out:
# Index(['Show', 'Rating', 'Review'], dtype='object')
# total length of audience review data: 65522; unique show: 563
#                                   Show  Rating  \
# 62391  Marvel's Agents of S.H.I.E.L.D.     5.0
# 51228               The Queen's Gambit     2.0
# 56717              The Thing About Pam     1.5
# 52436                     The Stranger     3.5
# 45377                         Sex/Life     5.0
#
#                                                   Review
# 62391  one of the best shows i loved it ...chloe benn...
# 51228  A way overrated tv series with an extremely sl...
# 56717  I like everything except the fact that Renee Z...
# 52436  Strong start to an intriguing mystery gets wea...
# 45377  Personally I LOVED this show. For me, it was a...

# %%
critic = pd.read_csv('critic_reviews.csv')
print(critic.columns)
print(f'total length of critic data: {critic.__len__()}; unique show: {critic.Show.unique().__len__()}')
critic.sample(5)
# Out:
# Index(['Show', 'Sentiment', 'Review'], dtype='object')
# total length of critic data: 14791; unique show: 495
#               Show  Sentiment  \
# 7979  Breaking Bad          1
# 1722          Evil          1
# 4986  The Outsider          1
# 1196  Schmigadoon!          0
# 152      Severance          1
#
#                                                  Review
# 7979  Its creator Vince Gilligan's extraordinary sto...
# 1722  Evil, since its start, has always been an intr...
# 4986  The Outsider is a superbly written, shot and a...
# 1196  There's too much talent here for Schmigadoon! ...
# 152   Black Mirror meets Eternal Sunshine of the Spo...

# %%
tv_show = pd.read_csv('tv_show_links.csv')
print(tv_show.columns)
print(f'total length of tv_show data: {tv_show.__len__()}')
tv_show.sample(5)
# Out:
# Index(['Network', 'Show', 'Critic Score', 'Audience Score', 'tv_link'], dtype='object')
# total length of tv_show data: 885
#          Network                 Show Critic Score Audience Score  \
# 271      HBO MAX                Girls          89%            75%
# 402  Prime Video  The Handmaid's Tale          83%            77%
# 795         VUDU      Game of Thrones          89%            85%
# 565         Hulu             Cardinal          87%            83%
# 566         Hulu       Criminal Minds           --            85%
#
#                                                tv_link
# 271            https://www.rottentomatoes.com/tv/girls
# 402  https://www.rottentomatoes.com/tv/the_handmaid...
# 795  https://www.rottentomatoes.com/tv/game_of_thrones
# 565         https://www.rottentomatoes.com/tv/cardinal
# 566   https://www.rottentomatoes.com/tv/criminal_minds

# %% [markdown]
# #### merge based on tv_show dataset

# %%
# grouping the review data first

## audience data
grouped_audience = audience.groupby('Show', dropna=False)

agg_audience_nob = pd.DataFrame({
        'nob_audience': grouped_audience.size()
}).reset_index()

agg_audience = grouped_audience.agg({
    'Rating': lambda x: list(pd.unique(x)), 
    'Review': lambda x: list(pd.unique(x))
})

audience_data = pd.merge(agg_audience_nob, agg_audience, on='Show')
audience_data.sample(5)
# Out:
#                                              Show  nob_audience  \
# 284                                         Ozark           174
# 335                              Sex and the City             2
# 356                         Star Trek: Enterprise            23
# 549  Winning Time: The Rise of the Lakers Dynasty            47
# 521                                        Undone            15
#
#                                                 Rating  \
# 284  [4.5, 3.0, 2.5, 0.5, 1.0, 5.0, 4.0, 3.5, 1.5, ...
# 335                                         [3.0, 3.5]
# 356                [3.5, 1.0, 5.0, 4.5, 4.0, 3.0, 0.5]
# 549                [0.5, 5.0, 4.0, 4.5, 3.5, 1.5, 2.5]
# 521                               [5.0, 0.5, 2.0, 4.5]
#
#                                                 Review
# 284  [First few episodes were slow, but man did it ...
# 335  [It was great back in the day but now it just ...
# 356  [The final season, which brought in Manny Coto...
# 549  [This show plays fast and loose with the truth...
# 521  [Theres no way to not watch this series. A tru...

# %%
## critics data
grouped_critics = critic.groupby('Show', dropna=False)

agg_critics_nob = pd.DataFrame({
        'nob_critics': grouped_critics.size()
}).reset_index()
agg_critics = grouped_critics.agg({
    'Sentiment': lambda x: list(pd.unique(x)), 
    'Review': lambda x: list(pd.unique(x))
})

critics_data = pd.merge(agg_critics_nob, agg_critics, on='Show')
critics_data.sample(5)
# Out:
#                                          Show  nob_critics Sentiment  \
# 410            The Sex Lives of College Girls           30    [1, 0]
# 489                         You Don't Know Me            5       [1]
# 233                          Once Upon a Time            7    [1, 0]
# 123            George Carlin's American Dream           19       [1]
# 215  Money Heist: Korea - Joint Economic Area           13    [1, 0]
#
#                                                 Review
# 410  [It's a credit to the sharp writing, entertain...
# 489  [The well-written, skillfully told four-part c...
# 233  [Season 7 got off to an admittedly bumpy start...
# 123  [Apatow has done much to illuminate the art fo...
# 215  [Themes regarding traditionalism versus global...

# %%
audience_data.rename(columns={'Review': 'Review_audience'}, inplace=True)
tv_show = pd.merge(tv_show, audience_data, on='Show', how='left')

critics_data.rename(columns={'Review': 'Review_critics'}, inplace=True)
tv_show = pd.merge(tv_show, critics_data, on='Show', how='left')


tv_show['matched_audience_indicator'] = tv_show['Review_audience'].notnull().astype(int)
tv_show['matched_critics_indicator'] = tv_show['Review_critics'].notnull().astype(int)

print(f'the matched pairs from audience review: {tv_show.matched_audience_indicator.sum()}')
print(f'the matched pairs from critics: {tv_show.matched_critics_indicator.sum()}')

tv_show['matched_all_review_indicator'] = (tv_show['matched_audience_indicator'] & tv_show['matched_critics_indicator']).astype(int)
print(f'the matched results from all review data: {tv_show.matched_all_review_indicator.sum()}')
# Out:
# the matched pairs from audience review: 746
# the matched pairs from critics: 673
# the matched results from all review data: 657

# %% [markdown]
# #### finalize the review dataset

# %% [markdown]
# ##### attach review information on profit information

# %%
# match with profit & production data

tv_show.rename(columns={'Show': 'title'}, inplace=True)
disney_plus = pd.merge(disney_plus, tv_show, on='title', how='left')

disney_plus.sample(5)
# Out:
#        imdb_id                         title  \
# 319  tt0385726                    Glory Road
# 328  tt0025200  The Grasshopper and the Ants
# 523  tt0120645              Meet the Deedles
# 31   tt0207972                         Annie
# 9    tt0113198                 A Goofy Movie
#
#                                                   plot   type     rated  year  \
# 319  In 1966, Texas Western coach Don Haskins led t...  movie        PG  2006
# 328  As in the classic fable, the grasshopper plays...  movie  Approved  1934
# 523  Two surfers end up as Yellowstone park rangers...  movie        PG  1998
# 31   A little orphan girl catches the attention of ...  movie   UNRATED  1999
# 9    When Max makes a preposterous promise to a gir...  movie         G  1995
#
#      released_at           added_at  runtime  \
# 319  13 Jan 2006   December 1, 2019  118 min
# 328  10 Feb 1934  November 12, 2019    8 min
# 523  27 Mar 1998  November 12, 2019   93 min
# 31   07 Nov 1999  November 12, 2019   90 min
# 9    07 Apr 1995  November 12, 2019   78 min
#
#                                                  genre  ... tv_link  \
# 319                            Biography, Drama, Sport  ...     NaN
# 328          Family, Comedy, Animation, Musical, Short  ...     NaN
# 523                                     Comedy, Family  ...     NaN
# 31                             Family, Comedy, Musical  ...     NaN
# 9    Animation, Adventure, Comedy, Family, Musical,...  ...     NaN
#
#     nob_audience Rating Review_audience nob_critics Sentiment  Review_critics  \
# 319          NaN    NaN             NaN         NaN       NaN             NaN
# 328          NaN    NaN             NaN         NaN       NaN             NaN
# 523          NaN    NaN             NaN         NaN       NaN             NaN
# 31           NaN    NaN             NaN         NaN       NaN             NaN
# 9            NaN    NaN             NaN         NaN       NaN             NaN
#
#      matched_audience_indicator matched_critics_indicator  \
# 319                         NaN                       NaN
# 328                         NaN                       NaN
# 523                         NaN                       NaN
# 31                          NaN                       NaN
# 9                           NaN                       NaN
#
#      matched_all_review_indicator
# 319                           NaN
# 328                           NaN
# 523                           NaN
# 31                            NaN
# 9                             NaN
#
# [5 rows x 38 columns]

# %%
valid_data = disney_plus.loc[((disney_plus['matched_profit_indicator']==1)&(disney_plus['matched_all_review_indicator']==1))]
## question: only 7 entries...

# %% [markdown]
# ##### attach profit information on review information

# %%
# match with profit & production data

# tv_show.rename(columns={'Show': 'title'}, inplace=True)
# tv_show = pd.merge(tv_show, disney_plus, on='title', how='left')

# valid_data = tv_show.loc[((tv_show['matched_profit_indicator']==1)&(tv_show['matched_all_review_indicator']==1))]
# print('total length of valid data: ', valid_data.__len__())
